# %% [markdown]
# <a href="https://colab.research.google.com/github/oghebbu/GoogleColabProjects/blob/main/comfyui_colab_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ComfyUI on Google Colab
# Run each cell step by step. Make sure GPU is enabled: Runtime → Change runtime type → GPU.

# %%
# Clone ComfyUI
# !git clone https://github.com/comfyanonymous/ComfyUI
# %cd ComfyUI

# Install dependencies
# !pip install -r requirements.txt

# %%
# Download SDXL model
# !mkdir -p models/checkpoints
# !wget -O models/checkpoints/sdxl_base_1.0.safetensors \
https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors

# %%
# Install cloudflared properly
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared
# !mv cloudflared /usr/local/bin

# %%
# Launch ComfyUI
import subprocess, threading

def run_comfy():
    subprocess.run(["python", "main.py", "--listen", "0.0.0.0", "--port", "8188"])

threading.Thread(target=run_comfy).start()

# %%
# %cd /content/ComfyUI

# %%
# !mkdir -p models/text_encoders
# !mkdir -p models/loras
# !mkdir -p models/diffusion_models
# !mkdir -p models/vae

# %%
# !wget -O models/text_encoders/qwen_3_4b.safetensors \
https://huggingface.co/Qwen/Qwen3-4B/resolve/main/qwen_3_4b.safetensors

# %%
# Create public URL
# !cloudflared tunnel --url http://localhost:8188
